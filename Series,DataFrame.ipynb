# %%
import numpy as np
import pandas as pd

# %%
from pandas import Series

# %%
s = Series([1,2,3,4,5])

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s = Series(["Hyd","Chennai","Pune","Banglore"])

# %%
s
# Out:
# 0         Hyd
# 1     Chennai
# 2        Pune
# 3    Banglore
# dtype: object

# %%
s1 = Series([10,20,30],index = [2,3,4])

# %%
s1
# Out:
# 2    10
# 3    20
# 4    30
# dtype: int64

# %%
s1[2]
# Out:
# 10

# %%
s1.values
# Out:
# array([10, 20, 30], dtype=int64)

# %%
s1.index
# Out:
# Int64Index([2, 3, 4], dtype='int64')

# %%
s1 = Series(np.arange(10),index = list("abcdefhijk"))

# %%
s1
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# f    5
# h    6
# i    7
# j    8
# k    9
# dtype: int32

# %%
s1[1]
# Out:
# 1

# %%
s1 = Series(["Chennai","Hyderabad","Banglore"],index = ['C','H','B'])

# %%
s1
# Out:
# C      Chennai
# H    Hyderabad
# B     Banglore
# dtype: object

# %%
s1["C"]
# Out:
# 'Chennai'

# %%
s1[0:2]
# Out:
# C      Chennai
# H    Hyderabad
# dtype: object

# %%
s1 = Series(np.arange(10),index = list("abcdefhijk"))

# %%
s1
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# f    5
# h    6
# i    7
# j    8
# k    9
# dtype: int32

# %%
a = s1 >5

# %%
s1[a]
# Out:
# h    6
# i    7
# j    8
# k    9
# dtype: int32

# %%
from pandas import Series, DataFrame

# %%
df1 = DataFrame(np.arange(1,17).reshape(4,4))

# %%
df1
# Out:
#     0   1   2   3
# 0   1   2   3   4
# 1   5   6   7   8
# 2   9  10  11  12
# 3  13  14  15  16

# %%
df2 = DataFrame(np.arange(1,26).reshape(5,5),index =list("abcde"))

# %%
df2
# Out:
#     0   1   2   3   4
# a   1   2   3   4   5
# b   6   7   8   9  10
# c  11  12  13  14  15
# d  16  17  18  19  20
# e  21  22  23  24  25

# %%
df3 = DataFrame(np.arange(1,26).reshape(5,5),index =list("abcde"),columns = ["c1","c2","c3","c4","c5"])

# %%
df3
# Out:
#    c1  c2  c3  c4  c5
# a   1   2   3   4   5
# b   6   7   8   9  10
# c  11  12  13  14  15
# d  16  17  18  19  20
# e  21  22  23  24  25

# %%
df3["c1"]
# Out:
# a     1
# b     6
# c    11
# d    16
# e    21
# Name: c1, dtype: int32

# %%
df3[["c1","c2"]]
# Out:
#    c1  c2
# a   1   2
# b   6   7
# c  11  12
# d  16  17
# e  21  22

# %%
df3[1:3]
# Out:
#    c1  c2  c3  c4  c5
# b   6   7   8   9  10
# c  11  12  13  14  15

# %%
df3["c1"]>15
# Out:
# a    False
# b    False
# c    False
# d     True
# e     True
# Name: c1, dtype: bool

# %%
df3[df3["c1"]>15]
# Out:
#    c1  c2  c3  c4  c5
# d  16  17  18  19  20
# e  21  22  23  24  25

# %%
df3 = DataFrame({'Company':list(["TCS","GOOGLE","YAHOO","WIPRO"]),'Ticker':list(["TCS","GOOG","YAH","WIP"]),'Price':list(np.arange(100,401,100))})
df3
# Out:
#   Company Ticker  Price
# 0     TCS    TCS    100
# 1  GOOGLE   GOOG    200
# 2   YAHOO    YAH    300
# 3   WIPRO    WIP    400

# %%
df3[df3['Price']>200]
# Out:
#   Company Ticker  Price
# 2   YAHOO    YAH    300
# 3   WIPRO    WIP    400

# %%
df3["Year"]=[2020,2022,2016,2021]

# %%
df3
# Out:
#   Company Ticker  Price  Year
# 0     TCS    TCS    100  2020
# 1  GOOGLE   GOOG    200  2022
# 2   YAHOO    YAH    300  2016
# 3   WIPRO    WIP    400  2021

# %%
del df3["Year"]

# %%
df3
# Out:
#   Company Ticker  Price
# 0     TCS    TCS    100
# 1  GOOGLE   GOOG    200
# 2   YAHOO    YAH    300
# 3   WIPRO    WIP    400

# %%
df4 = DataFrame(np.arange(1,26).reshape(5,5),index=list("abcde"),columns=list("vwxyz"))

# %%
df4
# Out:
#     v   w   x   y   z
# a   1   2   3   4   5
# b   6   7   8   9  10
# c  11  12  13  14  15
# d  16  17  18  19  20
# e  21  22  23  24  25

# %%
df4.iloc[:,1]
# Out:
# a     2
# b     7
# c    12
# d    17
# e    22
# Name: w, dtype: int32

# %%
df4.loc["a"]
# Out:
# v    1
# w    2
# x    3
# y    4
# z    5
# Name: a, dtype: int32

# %%
df4.iloc[:2,:]
# Out:
#    v  w  x  y   z
# a  1  2  3  4   5
# b  6  7  8  9  10

# %%
df4
# Out:
#     v   w   x   y   z
# a   1   2   3   4   5
# b   6   7   8   9  10
# c  11  12  13  14  15
# d  16  17  18  19  20
# e  21  22  23  24  25

# %%
df4.iloc[1:4,2:]
# Out:
#     x   y   z
# b   8   9  10
# c  13  14  15
# d  18  19  20

# %%
df4
# Out:
#     v   w   x   y   z
# a   1   2   3   4   5
# b   6   7   8   9  10
# c  11  12  13  14  15
# d  16  17  18  19  20
# e  21  22  23  24  25

# %%
df4.loc[["b","c"]]
# Out:
#     v   w   x   y   z
# b   6   7   8   9  10
# c  11  12  13  14  15

# %%
df4.loc["b"]["x"]
# Out:
# 8

# %%
df4.loc[:,"x"]
# Out:
# a     3
# b     8
# c    13
# d    18
# e    23
# Name: x, dtype: int32

# %%
df1 = DataFrame({'Name':list('ABCDEFGHIJ'),'Score 1':np.random.randint(1,101,10)})
df1
# Out:
#   Name  Score 1
# 0    A       33
# 1    B       76
# 2    C       75
# 3    D       68
# 4    E       66
# 5    F       54
# 6    G       42
# 7    H       38
# 8    I       74
# 9    J       47

# %%
df1.iloc[:2,1]=100
df1
# Out:
#   Name  Score 1
# 0    A      100
# 1    B      100
# 2    C       75
# 3    D       68
# 4    E       66
# 5    F       54
# 6    G       42
# 7    H       38
# 8    I       74
# 9    J       47

# %%
df1.iloc[:2,1]
df1
# Out:
#   Name  Score 1
# 0    A      100
# 1    B      100
# 2    C       75
# 3    D       68
# 4    E       66
# 5    F       54
# 6    G       42
# 7    H       38
# 8    I       74
# 9    J       47

# %%
df1.sort_values(by = "Score 1")
df1.sort_values(by = "Score 1",ascending = False)
# Out:
#   Name  Score 1
# 0    A      100
# 1    B      100
# 2    C       75
# 8    I       74
# 3    D       68
# 4    E       66
# 5    F       54
# 9    J       47
# 6    G       42
# 7    H       38

# %%
df1["Score 2"]= list(np.random.randint(1,101,10))

# %%
df1
# Out:
#   Name  Score 1  Score 2
# 0    A      100       25
# 1    B      100       83
# 2    C       75        9
# 3    D       68       60
# 4    E       66       37
# 5    F       54       79
# 6    G       42       83
# 7    H       38       16
# 8    I       74       27
# 9    J       47       65

# %%
df2 = df1.sort_values(by = ['Score 1','Score 2'])
df2
# Out:
#   Name  Score 1  Score 2
# 7    H       38       16
# 6    G       42       83
# 9    J       47       65
# 5    F       54       79
# 4    E       66       37
# 3    D       68       60
# 8    I       74       27
# 2    C       75        9
# 0    A      100       25
# 1    B      100       83

# %%
df2.sort_index()
# Out:
#   Name  Score 1  Score 2
# 0    A      100       25
# 1    B      100       83
# 2    C       75        9
# 3    D       68       60
# 4    E       66       37
# 5    F       54       79
# 6    G       42       83
# 7    H       38       16
# 8    I       74       27
# 9    J       47       65

# %%
df2.sort_index(ascending= False)
# Out:
#   Name  Score 1  Score 2
# 9    J       47       65
# 8    I       74       27
# 7    H       38       16
# 6    G       42       83
# 5    F       54       79
# 4    E       66       37
# 3    D       68       60
# 2    C       75        9
# 1    B      100       83
# 0    A      100       25

# %%
df2.sort_values(by = ["Score 1"], inplace = True)

# %%
df1.sort_values(by = ['Score 1','Score 2'],ascending=[True,False])
df1
# Out:
#   Name  Score 1  Score 2
# 0    A      100       25
# 1    B      100       83
# 2    C       75        9
# 3    D       68       60
# 4    E       66       37
# 5    F       54       79
# 6    G       42       83
# 7    H       38       16
# 8    I       74       27
# 9    J       47       65

# %%
df2
# Out:
#   Name  Score 1  Score 2
# 7    H       38       16
# 6    G       42       83
# 9    J       47       65
# 5    F       54       79
# 4    E       66       37
# 3    D       68       60
# 8    I       74       27
# 2    C       75        9
# 0    A      100       25
# 1    B      100       83

# %% [markdown]
# # Rank

# %%
df = DataFrame({"Name":list("abcdefghij"),"Score 1":range(1,101,10)})

# %%
df
# Out:
#   Name  Score 1
# 0    a        1
# 1    b       11
# 2    c       21
# 3    d       31
# 4    e       41
# 5    f       51
# 6    g       61
# 7    h       71
# 8    i       81
# 9    j       91

# %%
df.iloc[2:4,1:]=110

# %%
df
# Out:
#   Name  Score 1
# 0    a        1
# 1    b       11
# 2    c      110
# 3    d      110
# 4    e       41
# 5    f       51
# 6    g       61
# 7    h       71
# 8    i       81
# 9    j       91

# %%
df["Rank"]=df["Score 1"].rank()

# %%
df
# Out:
#   Name  Score 1  Rank
# 0    a        1   1.0
# 1    b       11   2.0
# 2    c      110   9.5
# 3    d      110   9.5
# 4    e       41   3.0
# 5    f       51   4.0
# 6    g       61   5.0
# 7    h       71   6.0
# 8    i       81   7.0
# 9    j       91   8.0

# %%
df["Rank d"]=df["Score 1"].rank(ascending = False)

# %%
df
# Out:
#   Name  Score 1  Rank  Rank d
# 0    a        1   1.0    10.0
# 1    b       11   2.0     9.0
# 2    c      110   9.5     1.5
# 3    d      110   9.5     1.5
# 4    e       41   3.0     8.0
# 5    f       51   4.0     7.0
# 6    g       61   5.0     6.0
# 7    h       71   6.0     5.0
# 8    i       81   7.0     4.0
# 9    j       91   8.0     3.0

# %%
df["rank min"]=df1["Score 1"].rank(method="min",ascending=False)

# %%
df
# Out:
#   Name  Score 1  Rank  Rank d  rank min
# 0    a        1   1.0    10.0       1.0
# 1    b       11   2.0     9.0       1.0
# 2    c      110   9.5     1.5       3.0
# 3    d      110   9.5     1.5       5.0
# 4    e       41   3.0     8.0       6.0
# 5    f       51   4.0     7.0       7.0
# 6    g       61   5.0     6.0       9.0
# 7    h       71   6.0     5.0      10.0
# 8    i       81   7.0     4.0       4.0
# 9    j       91   8.0     3.0       8.0

# %%
df["rank max"]=df1["Score 1"].rank(method="max")

# %%
df
# Out:
#   Name  Score 1  Rank  Rank d  rank min  rank max
# 0    a        1   1.0    10.0       1.0      10.0
# 1    b       11   2.0     9.0       1.0      10.0
# 2    c      110   9.5     1.5       3.0       8.0
# 3    d      110   9.5     1.5       5.0       6.0
# 4    e       41   3.0     8.0       6.0       5.0
# 5    f       51   4.0     7.0       7.0       4.0
# 6    g       61   5.0     6.0       9.0       2.0
# 7    h       71   6.0     5.0      10.0       1.0
# 8    i       81   7.0     4.0       4.0       7.0
# 9    j       91   8.0     3.0       8.0       3.0

# %%
df["dense"] = df1["Score 1"].rank(method="dense",ascending = False)

# %%
df
# Out:
#   Name  Score 1  Rank  Rank d  rank min  rank max  dense
# 0    a        1   1.0    10.0       1.0      10.0    1.0
# 1    b       11   2.0     9.0       1.0      10.0    1.0
# 2    c      110   9.5     1.5       3.0       8.0    2.0
# 3    d      110   9.5     1.5       5.0       6.0    4.0
# 4    e       41   3.0     8.0       6.0       5.0    5.0
# 5    f       51   4.0     7.0       7.0       4.0    6.0
# 6    g       61   5.0     6.0       9.0       2.0    8.0
# 7    h       71   6.0     5.0      10.0       1.0    9.0
# 8    i       81   7.0     4.0       4.0       7.0    3.0
# 9    j       91   8.0     3.0       8.0       3.0    7.0

# %%
df["Rank_First"] = df1["Score 1"].rank(method="first")

# %%
df
# Out:
#   Name  Score 1  Rank  Rank d  rank min  rank max  dense  Rank_First
# 0    a        1   1.0    10.0       1.0      10.0    1.0         9.0
# 1    b       11   2.0     9.0       1.0      10.0    1.0        10.0
# 2    c      110   9.5     1.5       3.0       8.0    2.0         8.0
# 3    d      110   9.5     1.5       5.0       6.0    4.0         6.0
# 4    e       41   3.0     8.0       6.0       5.0    5.0         5.0
# 5    f       51   4.0     7.0       7.0       4.0    6.0         4.0
# 6    g       61   5.0     6.0       9.0       2.0    8.0         2.0
# 7    h       71   6.0     5.0      10.0       1.0    9.0         1.0
# 8    i       81   7.0     4.0       4.0       7.0    3.0         7.0
# 9    j       91   8.0     3.0       8.0       3.0    7.0         3.0

# %%
df =DataFrame([[1,2,3],[4,5,6]])
df
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
